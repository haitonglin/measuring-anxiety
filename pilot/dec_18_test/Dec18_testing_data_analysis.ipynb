# %%
# %matplotlib inline
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import sklearn
import warnings 
warnings.filterwarnings('ignore')

# %% [markdown]
# ---

# %%
during=pd.read_csv("during_cpt.csv")
during
# Out:
#      Time    HRV   GSR
# 0    2093  1.048  1460
# 1    3103  1.048  1460
# 2    3448  1.048  1460
# 3    4135  1.045  1459
# 4    4824  1.043  1459
# ..    ...    ...   ...
# 85  59456  1.019  1422
# 86  60461  1.019  1421
# 87  61178  1.018  1420
# 88  61535  1.018  1420
# 89  62251  1.019  1419
#
# [90 rows x 3 columns]

# %%
during.describe()
# Out:
#                Time       HRV         GSR
# count     90.000000  90.00000    90.00000
# mean   32368.688889   1.02560  1440.90000
# std    17694.329753   0.00831    12.36073
# min     2093.000000   1.01800  1419.00000
# 25%    17341.750000   1.01900  1431.00000
# 50%    32392.500000   1.02100  1441.50000
# 75%    47502.500000   1.02950  1451.75000
# max    62251.000000   1.04800  1460.00000

# %%
plt.figure(figsize=(10,8))
plt.title("HRV during CPT")
plt.plot(during['Time'],during['HRV'])
plt.show()

# %%
plt.figure(figsize=(10,8))
plt.title("GSR during CPT")
plt.plot(during['Time'],during['GSR'])
plt.show()

# %% [markdown]
# ---

# %%
pre=pd.read_csv("pre.csv")
pre
# Out:
#      Time    HRV   GSR
# 0     129  1.329  1794
# 1     473  1.329  1792
# 2    1156  1.329  1791
# 3    2195  1.299  1790
# 4    2880  1.299  1789
# ..    ...    ...   ...
# 69  51534  1.029  1722
# 70  52256  1.027  1720
# 71  52617  1.027  1717
# 72  53341  1.026  1718
# 73  54017  1.026  1718
#
# [74 rows x 3 columns]

# %%
pre.describe()
# Out:
#                Time        HRV          GSR
# count     74.000000  74.000000    74.000000
# mean   28341.094595   1.118878  1755.418919
# std    15986.997331   0.088218    22.123568
# min      129.000000   1.026000  1717.000000
# 25%    15958.500000   1.046250  1735.000000
# 50%    29595.500000   1.087000  1755.000000
# 75%    41530.750000   1.182750  1774.000000
# max    54017.000000   1.329000  1794.000000

# %%
plt.figure(figsize=(10,8))
plt.title("HRV before CPT")
plt.plot(pre['Time'],pre['HRV'],color="red")
plt.show()

# %%
plt.figure(figsize=(10,8))
plt.title("GSR before CPT")
plt.plot(pre['Time'],pre['GSR'], color="red")
plt.show()

# %% [markdown]
# ---

# %%
post=pd.read_csv("post.csv")
post
# Out:
#      Time    HRV   GSR
# 0     318  1.021  1417
# 1    1003  1.022  1416
# 2    1704  1.022  1415
# 3    2388  1.022  1415
# 4    2748  1.021  1414
# ..    ...    ...   ...
# 81  54097  1.013  1373
# 82  54781  1.012  1370
# 83  55468  1.013  1373
# 84  56151  1.013  1373
# 85  56845  1.012  1375
#
# [86 rows x 3 columns]

# %%
post.describe()
# Out:
#                Time        HRV          GSR
# count     86.000000  86.000000    86.000000
# mean   28828.302326   1.016198  1393.744186
# std    16521.272736   0.003173    13.421831
# min      318.000000   1.012000  1370.000000
# 25%    14589.500000   1.013000  1382.250000
# 50%    29427.000000   1.016000  1393.000000
# 75%    42882.750000   1.018000  1405.000000
# max    56845.000000   1.022000  1417.000000

# %%
plt.figure(figsize=(10,8))
plt.title("HRV after CPT")
plt.plot(post['Time'],post['HRV'],color="green")
plt.show()

# %%
plt.figure(figsize=(10,8))
plt.title("GSR after CPT")
plt.plot(post['Time'],post['GSR'],color="green")
plt.show()

# %% [markdown]
# ---

# %%
x = np.linspace(1,74,num=74)
y1 = during['HRV'].head(74)
y2 = post['HRV'].head(74)

# %%
plt.figure(figsize=(10,8))
plt.title('HRV Changes')
plt.plot(x,pre['HRV'],label='pre-CPT')
plt.plot(x,y1,label='during-CPT')
plt.plot(x,y2,label='post-CPT')
plt.legend()
plt.show()

# %%
y3 = during['GSR'].head(74)
y4 = post['GSR'].head(74)

# %%
plt.figure(figsize=(10,8))
plt.title('GSR Changes')
plt.plot(x,pre['GSR'],label='pre-CPT')
plt.plot(x,y3,label='during-CPT')
plt.plot(x,y4,label='post-CPT')
plt.legend()
plt.show()

# %%
df_all=pd.concat([pre,during,post],keys=['pre', 'during','post'])
df_all
# Out:
#           Time    HRV   GSR
# pre  0     129  1.329  1794
#      1     473  1.329  1792
#      2    1156  1.329  1791
#      3    2195  1.299  1790
#      4    2880  1.299  1789
# ...        ...    ...   ...
# post 81  54097  1.013  1373
#      82  54781  1.012  1370
#      83  55468  1.013  1373
#      84  56151  1.013  1373
#      85  56845  1.012  1375
#
# [250 rows x 3 columns]

# %%
plt.figure(figsize=(10,8))
plt.title('GSR Changes')
x=np.linspace(0,249,250)
y=df_all['GSR']
plt.plot(x,y)
plt.axvline(x = 73, color = 'grey', label = 'axvline - full height',linestyle=':')
plt.axvline(x = 163, color = 'grey', label = 'axvline - full height',linestyle=':')
plt.show()

# %%
plt.figure(figsize=(10,8))
plt.title('HRV Changes')
x=np.linspace(0,249,250)
y=df_all['HRV']
plt.plot(x,y)
plt.axvline(x = 73, color = 'grey', label = 'axvline - full height',linestyle=':')
plt.axvline(x = 163, color = 'grey', label = 'axvline - full height',linestyle=':')
plt.show()
