# %%
# %matplotlib inline
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import sklearn
import warnings 
warnings.filterwarnings('ignore')

# %%
pre=pd.read_csv("pre.csv")
pre.describe()
# Out:
#                 Time           rr          hr         hrv          gsr
# count     272.000000   272.000000  272.000000  272.000000   272.000000
# mean   145080.316176  1120.595588   54.235294    1.288096  1171.386029
# std     89093.742026   575.084956    7.263349    0.077849    45.236014
# min       223.000000   619.000000   40.000000    1.125000  1109.000000
# 25%     67436.500000   798.000000   49.000000    1.229000  1130.000000
# 50%    140547.000000   896.000000   54.000000    1.289500  1164.000000
# 75%    220187.750000  1020.000000   60.000000    1.348500  1209.000000
# max    304198.000000  5399.000000   69.000000    1.453000  1257.000000

# %%
cpt=pd.read_csv("cpt.csv")
cpt.describe()
# Out:
#                 time           rr         hr        hrv          gsr
# count      97.000000    97.000000  97.000000  97.000000    97.000000
# mean    66211.515464  1289.587629  45.907216   1.311918  1014.824742
# std     36731.734883  1138.123481  10.541666   0.076743     6.970190
# min      1547.000000   230.000000  30.000000   1.171000   999.000000
# 25%     31561.000000   663.000000  36.000000   1.258000  1009.000000
# 50%     71729.000000   763.000000  44.000000   1.309000  1013.000000
# 75%     97860.000000  1507.000000  56.000000   1.373000  1020.000000
# max    121550.000000  8186.000000  68.000000   1.438000  1031.000000

# %%
dbreak=pd.read_csv("break.csv")
dbreak.describe()
# Out:
#                 time            rr          hr         hrv          gsr
# count     109.000000    109.000000  109.000000  109.000000   109.000000
# mean   139415.651376   2761.871560   23.128440    1.607633  1023.944954
# std     93293.906465   2536.101014    6.151033    0.150041    12.387146
# min       659.000000    282.000000   12.000000    1.220000   998.000000
# 25%     54713.000000   1001.000000   19.000000    1.552000  1015.000000
# 50%    117417.000000   2050.000000   23.000000    1.624000  1027.000000
# 75%    225258.000000   3449.000000   28.000000    1.722000  1036.000000
# max    299736.000000  13233.000000   35.000000    1.864000  1041.000000

# %%
math=pd.read_csv("math.csv")
math.describe()
# Out:
#                 time           rr         hr         hrv          gsr
# count     100.000000   100.000000  100.00000  100.000000   100.000000
# mean    60980.780000  1225.480000   49.52000    1.349890  1002.360000
# std     36040.316272   690.851772    4.50248    0.059181     2.713677
# min        96.000000   330.000000   40.00000    1.227000   997.000000
# 25%     30298.000000   764.750000   46.00000    1.314750  1000.000000
# 50%     57940.000000   855.000000   50.00000    1.346000  1003.000000
# 75%     93368.750000  1610.250000   53.00000    1.389000  1004.000000
# max    121221.000000  3689.000000   64.00000    1.465000  1007.000000

# %%
post=pd.read_csv("post.csv")
post.describe()
# Out:
#                time           rr         hr        hrv         gsr
# count     47.000000    47.000000  47.000000  47.000000   47.000000
# mean   32147.744681  1254.723404  46.595745   1.449745  975.170213
# std    17046.979830   830.341043   3.959905   0.034919    1.698070
# min      854.000000   379.000000  38.000000   1.384000  971.000000
# 25%    18104.500000   752.000000  43.500000   1.423000  974.000000
# 50%    33889.000000   850.000000  46.000000   1.450000  976.000000
# 75%    46374.500000  1683.000000  50.000000   1.466500  977.000000
# max    59878.000000  4214.000000  54.000000   1.541000  978.000000

# %%
alld=pd.read_csv("all.csv")
alld
# Out:
#      time    rr  hr    hrv   gsr
# 0       1   777  54  1.338  1257
# 1       2   726  54  1.315  1256
# 2       3   812  56  1.302  1257
# 3       4   864  56  1.302  1255
# 4       5   779  54  1.348  1254
# ..    ...   ...  ..    ...   ...
# 620   621   757  52  1.515   973
# 621   622   764  54  1.492   973
# 622   623   815  52  1.492   972
# 623   624  1670  50  1.469   972
# 624   625  1699  50  1.469   971
#
# [625 rows x 5 columns]

# %%
x=alld['time']

plt.figure(figsize=(20,8))
#plt.plot(x,alld['rr'],label='rr interval')
#plt.plot(x,alld['hr'],label='heart rate')
#plt.plot(x,alld['hrv'],label='hrv')
plt.plot(x,alld['gsr'],label='gsr')
plt.axvline(x = 272, color = 'grey', linestyle=':')
plt.axvline(x = 369, color = 'grey', linestyle=':')
plt.axvline(x = 479, color = 'grey', linestyle=':')
plt.axvline(x = 579, color = 'grey', linestyle=':') 
plt.legend()
plt.show()
